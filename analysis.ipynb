# %%
final_list = []  # initializing an empty list for the entire file

for line in open('billionaires.csv'):
    cleaned_line = line.strip()
    cleaned_list = cleaned_line.split(',')
    final_list.append(cleaned_list)  
printed_names = []
for row in final_list:
    name = row[0]
    country = row[10]
    if country == '"United States"' and name not in printed_names: #print only usa billionaires and not the same name of them 
        print(row)
        printed_names.append(name)
# Out:
# ['"Bill Gates"', '"1"', '"1996"', '"1975"', '"Microsoft"', '"founder"', '" Software"', '"new"', '"40"', '"male"', '"United States"', '"USA"', '"8100000000000.0"', '"North America"', '"founder non-finance"', '"18.5"', '"New Sectors"', '"True"', '"Technology-Computer"', '"not inherited"', '"True"', '"True"']
# ['"Warren Buffett"', '"2"', '"1996"', '"1962"', '"Berkshire Hathaway"', '"founder"', '" Finance"', '"new"', '"65"', '"male"', '"United States"', '"USA"', '"8100000000000.0"', '"North America"', '"founder non-finance"', '"15.0"', '"Traded Sectors"', '"True"', '"Consumer"', '"not inherited"', '"True"', '"True"']
# ['"Paul Allen"', '"3"', '"2001"', '"1975"', '"Microsoft"', '"founder"', '"technology"', '"new"', '"48"', '"male"', '"United States"', '"USA"', '"10600000000000.0"', '"North America"', '"founder non-finance"', '"30.4"', '"New Sectors"', '"True"', '"Technology-Computer"', '"not inherited"', '"True"', '"True"']
# ...

# %%
import pandas as pd 
billionaires = pd.read_csv("billionaires.csv")
billionaires.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# ...

# %%
billionaires['location.country code']
# Out:
# 0          USA
# 1          USA
# 2          USA
# 3          USA
# 4          USA
#          ...
# 2609    Taiwan
# 2610       CHN
# 2611       CHN
# 2612       CZE
# 2613       CHN
# Name: location.country code, Length: 2614, dtype: object

# %%
billionaires.iloc[0]
# Out:
# name                                 Bill Gates
# rank                                          1
# year                                       1996
# company.founded                            1975
# company.name                          Microsoft
# company.relationship                    founder
# company.sector                         Software
# company.type                                new
# demographics.age                             40
# demographics.gender                        male
# location.citizenship              United States
# location.country code                       USA
# location.gdp                    8100000000000.0
# location.region                   North America
# wealth.type                 founder non-finance
# wealth.worth in billions                   18.5
# wealth.how.category                 New Sectors
# wealth.how.from emerging                   True
# wealth.how.industry         Technology-Computer
# wealth.how.inherited              not inherited
# ...

# %%
billionaires.iloc[0,10]
# Out:
# 'United States'

# %%
billionaires.iloc[:11,10]
# Out:
# 0     United States
# 1     United States
# 2     United States
# 3     United States
# 4     United States
# 5            Mexico
# 6       Switzerland
# 7     United States
# 8             Spain
# 9         Hong Kong
# 10    United States
# Name: location.citizenship, dtype: object

# %%
billionaires.iloc[[299,405],10]
# Out:
# 299    United States
# 405            Japan
# Name: location.citizenship, dtype: object

# %%
billionaires['location.country code'] != 'USA'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2609     True
# 2610     True
# 2611     True
# 2612     True
# 2613     True
# Name: location.country code, Length: 2614, dtype: bool

# %%
billionaires.loc[billionaires['location.country code'] != 'USA']
# Out:
#                          name  rank  year  company.founded  \
# 5            Carlos Slim Helu     2  2014             1990
# 6     Oeri Hoffman and Sacher     3  1996             1896
# 8              Amancio Ortega     3  2014             1975
# 9                Lee Shau Kee     4  1996             1976
# 12               Tsai Wan-lin     5  1996             1962
# ...                       ...   ...   ...              ...
# 2609              Wu Chung-Yi  1565  2014             1991
# 2610                 Wu Xiong  1565  2014             1999
# 2611                Yang Keng  1565  2014                0
# 2612            Zdenek Bakala  1565  2014             1994
# 2613              Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 5                              Telmex              founder
# 6                F. Hoffmann-La Roche                  NaN
# 8                                Zara              founder
# ...

# %%
billionaires.loc[(billionaires['location.country code'] != 'USA') & (billionaires['demographics.gender'] == 'female')]
# Out:
#                      name  rank  year  company.founded  \
# 31         Johanna Quandt    11  1996             1916
# 32    Liliane Bettencourt    11  2014             1909
# 34         Johanna Quandt    12  2001             1916
# 43    Liliane Bettencourt    15  2001             1909
# 94        Kirsten Rausing    31  2001             1951
# ...                   ...   ...   ...              ...
# 2563             Ina Chan  1565  2014             1962
# 2564         Jeanine Dick  1565  2014             1968
# 2571         Lam Fong Ngo  1565  2014             1997
# 2578         Liu Xiaomeng  1565  2014             1990
# 2582     Monika Schoeller  1565  2014             1948
#
#                                    company.name company.relationship  \
# 31                                          BMW             relation
# 32                                      L'Oreal             relation
# 34                                          BMW             relation
# ...

# %%
billionaires.columns
# Out:
# Index(['name', 'rank', 'year', 'company.founded', 'company.name',
#        'company.relationship', 'company.sector', 'company.type',
#        'demographics.age', 'demographics.gender', 'location.citizenship',
#        'location.country code', 'location.gdp', 'location.region',
#        'wealth.type', 'wealth.worth in billions', 'wealth.how.category',
#        'wealth.how.from emerging', 'wealth.how.industry',
#        'wealth.how.inherited', 'wealth.how.was founder',
#        'wealth.how.was political'],
#       dtype='object')

# %%
billionaires['age_when_company_founded'] = billionaires['year'] - billionaires['company.founded']
billionaires.columns
# Out:
# Index(['name', 'rank', 'year', 'company.founded', 'company.name',
#        'company.relationship', 'company.sector', 'company.type',
#        'demographics.age', 'demographics.gender', 'location.citizenship',
#        'location.country code', 'location.gdp', 'location.region',
#        'wealth.type', 'wealth.worth in billions', 'wealth.how.category',
#        'wealth.how.from emerging', 'wealth.how.industry',
#        'wealth.how.inherited', 'wealth.how.was founder',
#        'wealth.how.was political', 'age_when_company_founded'],
#       dtype='object')

# %%
billionaires.head
# Out:
# <bound method NDFrame.head of                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# ...

# %%
billionaires['wealth.worth in billions'].describe()
# Out:
# count    2614.000000
# mean        3.531943
# std         5.088813
# min         1.000000
# 25%         1.400000
# 50%         2.000000
# 75%         3.500000
# max        76.000000
# Name: wealth.worth in billions, dtype: float64

# %%
billionaires['wealth.worth in billions'].value_counts()
# Out:
# wealth.worth in billions
# 1.1     175
# 1.0     171
# 1.2     151
# 1.3     147
# 1.4     120
#        ...
# 14.9      1
# 15.1      1
# 10.8      1
# 24.5      1
# 17.8      1
# Name: count, Length: 183, dtype: int64

# %%
def convert_wealth(w):
    return (w//1)
billionaires['wealth.worth in billions'].apply(convert_wealth)
# Out:
# 0       18.0
# 1       58.0
# 2       76.0
# 3       15.0
# 4       32.0
#         ...
# 2609     1.0
# 2610     1.0
# 2611     1.0
# 2612     1.0
# 2613     1.0
# Name: wealth.worth in billions, Length: 2614, dtype: float64

# %%
billionaires.columns = billionaires.columns.str.replace('.', '_', regex=False)
print(billionaires.columns)
# Out:
# Index(['name', 'rank', 'year', 'company_founded', 'company_name',
#        'company_relationship', 'company_sector', 'company_type',
#        'demographics_age', 'demographics_gender', 'location_citizenship',
#        'location_country code', 'location_gdp', 'location_region',
#        'wealth_type', 'wealth_worth in billions', 'wealth_how_category',
#        'wealth_how_from emerging', 'wealth_how_industry',
#        'wealth_how_inherited', 'wealth_how_was founder',
#        'wealth_how_was political', 'age_when_company_founded'],
#       dtype='object')

# %%
gender_counts = billionaires['demographics_gender'].value_counts()
print(gender_counts)
# Out:
# demographics_gender
# male              2328
# female             249
# married couple       3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

gender_counts.plot(kind='bar')

plt.title('Number of Billionaires by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
import matplotlib.pyplot as plt

gender_counts.plot(kind='bar' ,color=['blue', 'pink'])

plt.title('Number of Billionaires by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
billionaires.groupby(['year', 'demographics_gender']).size().unstack().plot( #had to search (size = counts the rows) unstack = moves gender into columns and plot does the graphing
    kind='line',
    figsize=(12,6)
)
# Out:
# <Axes: xlabel='year'>

# %%
billionaires.assign(
    wealth_simple= billionaires['wealth_type'].apply(
        lambda x: 'inherited' if str(x).lower() == 'inherited' else 'other'
    )
).groupby(['demographics_gender', 'wealth_simple']).size().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='demographics_gender'>

# %%
billionaires['country_simple'] = billionaires['location_country code'].apply(
    lambda x: 'USA' if str(x).upper() == 'USA' else 'Other'
)
billionaires['country_simple'].value_counts().plot(kind='bar', figsize=(6,4))

plt.title('Billionaires: USA vs Other Countries')
plt.xlabel('Country Group')
plt.ylabel('Number of People')

plt.show()

# %%
billionaires.groupby('demographics_gender')['demographics_age'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='demographics_gender'>

# %%
female = billionaires[billionaires['demographics_gender'] == 'female']
female['wealth_how_industry'].value_counts().head(10).plot(kind='barh')
plt.xlabel('Number of Female Billionaires')
plt.ylabel('Industry')
plt.title('Top 10 Industries of Female Billionaires')
# Out:
# Text(0.5, 1.0, 'Top 10 Industries of Female Billionaires')

# %%
male = [df['demographics_gender'] == 'male']

male['wealth_how_industry'].value_counts().head(10).plot(kind='barh')

plt.xlabel('Number of Male Billionaires')
plt.ylabel('Industry')
plt.title('Top 10 Industries of Male Billionaires')

plt.show()
